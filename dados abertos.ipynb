# %%
# %sql
CREATE OR REPLACE TABLE silver_fluxo_caixa_eleitoral AS

-- PARTE 1: DESPESAS (Saídas de Caixa)
SELECT 
    'DESPESA' AS TIPO_TRANSACAO,
    SG_UF AS ESTADO,
    TRANSLATE(NM_UE, 'ÁÀÂÃÄÅÉÈÊËÍÌÎÏÓÒÔÕÖÚÙÛÜÇáàâãäåéèêëíìîïóòôõöúùûüç', 'AAAAAAEEEEIIIIOOOOOUUUUCaaaaaaeeeeiiiiooooouuuuc') AS MUNICIPIO,
    TRANSLATE(DS_CARGO, 'ÁÀÂÃÄÅÉÈÊËÍÌÎÏÓÒÔÕÖÚÙÛÜÇáàâãäåéèêëíìîïóòôõöúùûüç', 'AAAAAAEEEEIIIIOOOOOUUUUCaaaaaaeeeeiiiiooooouuuuc') AS CARGO,
    SG_PARTIDO AS PARTIDO,
    TRANSLATE(NM_CANDIDATO, 'ÁÀÂÃÄÅÉÈÊËÍÌÎÏÓÒÔÕÖÚÙÛÜÇáàâãäåéèêëíìîïóòôõöúùûüç', 'AAAAAAEEEEIIIIOOOOOUUUUCaaaaaaeeeeiiiiooooouuuuc') AS CANDIDATO,
    NR_CNPJ_PRESTADOR_CONTA AS CNPJ_CAMPANHA,
    
    NR_CPF_CNPJ_FORNECEDOR AS CPF_CNPJ_CONTRAPARTE,
    TRANSLATE(NM_FORNECEDOR, 'ÁÀÂÃÄÅÉÈÊËÍÌÎÏÓÒÔÕÖÚÙÛÜÇáàâãäåéèêëíìîïóòôõöúùûüç', 'AAAAAAEEEEIIIIOOOOOUUUUCaaaaaaeeeeiiiiooooouuuuc') AS NOME_CONTRAPARTE,
    TRANSLATE(DS_CNAE_FORNECEDOR, 'ÁÀÂÃÄÅÉÈÊËÍÌÎÏÓÒÔÕÖÚÙÛÜÇáàâãäåéèêëíìîïóòôõöúùûüç', 'AAAAAAEEEEIIIIOOOOOUUUUCaaaaaaeeeeiiiiooooouuuuc') AS SETOR_ECONOMICO,
    
    DT_DESPESA AS DATA_TRANSACAO,
    CAST(REPLACE(VR_DESPESA_CONTRATADA, ',', '.') AS DECIMAL(18,2)) AS VALOR_FINANCEIRO
FROM read_files(
    '/Workspace/Repos/GITHUB/dados-abertos-tse-2026/BRONZE/despesas_contratadas_candidatos_2026_*.csv',
    format => 'csv', header => 'true', sep => ';', encoding => 'ISO-8859-1'
)
WHERE VR_DESPESA_CONTRATADA IS NOT NULL

UNION ALL

-- PARTE 2: RECEITAS (Entradas de Caixa)
SELECT 
    'RECEITA' AS TIPO_TRANSACAO,
    SG_UF AS ESTADO,
    TRANSLATE(NM_UE, 'ÁÀÂÃÄÅÉÈÊËÍÌÎÏÓÒÔÕÖÚÙÛÜÇáàâãäåéèêëíìîïóòôõöúùûüç', 'AAAAAAEEEEIIIIOOOOOUUUUCaaaaaaeeeeiiiiooooouuuuc') AS MUNICIPIO,
    TRANSLATE(DS_CARGO, 'ÁÀÂÃÄÅÉÈÊËÍÌÎÏÓÒÔÕÖÚÙÛÜÇáàâãäåéèêëíìîïóòôõöúùûüç', 'AAAAAAEEEEIIIIOOOOOUUUUCaaaaaaeeeeiiiiooooouuuuc') AS CARGO,
    SG_PARTIDO AS PARTIDO,
    TRANSLATE(NM_CANDIDATO, 'ÁÀÂÃÄÅÉÈÊËÍÌÎÏÓÒÔÕÖÚÙÛÜÇáàâãäåéèêëíìîïóòôõöúùûüç', 'AAAAAAEEEEIIIIOOOOOUUUUCaaaaaaeeeeiiiiooooouuuuc') AS CANDIDATO,
    NR_CNPJ_PRESTADOR_CONTA AS CNPJ_CAMPANHA,
    
    NR_CPF_CNPJ_DOADOR AS CPF_CNPJ_CONTRAPARTE,
    TRANSLATE(NM_DOADOR, 'ÁÀÂÃÄÅÉÈÊËÍÌÎÏÓÒÔÕÖÚÙÛÜÇáàâãäåéèêëíìîïóòôõöúùûüç', 'AAAAAAEEEEIIIIOOOOOUUUUCaaaaaaeeeeiiiiooooouuuuc') AS NOME_CONTRAPARTE,
    TRANSLATE(DS_CNAE_DOADOR, 'ÁÀÂÃÄÅÉÈÊËÍÌÎÏÓÒÔÕÖÚÙÛÜÇáàâãäåéèêëíìîïóòôõöúùûüç', 'AAAAAAEEEEIIIIOOOOOUUUUCaaaaaaeeeeiiiiooooouuuuc') AS SETOR_ECONOMICO,
    
    DT_RECEITA AS DATA_TRANSACAO,
    CAST(REPLACE(VR_RECEITA, ',', '.') AS DECIMAL(18,2)) AS VALOR_FINANCEIRO
FROM read_files(
    '/Workspace/Repos/GITHUB/dados-abertos-tse-2026/BRONZE/receitas_candidatos_2026_*.csv',
    format => 'csv', header => 'true', sep => ';', encoding => 'ISO-8859-1'
)
WHERE VR_RECEITA IS NOT NULL;
